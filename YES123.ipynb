# %%
import requests as r
joblist=[]
for index in range(0,5):
    url="https://www.yes123.com.tw/admin/job_refer_list.asp"
    head={}
    payload={
            "find_key1": "Android",
            "search_feature": "",
            "search_work": "請選擇職務",
            "search_multi_loc": "請選擇地區 ",
            "_rdo_1": "1",
            "search_subj": "",
            "search_work4": "請選擇職務",
            "search_multi_loc4": "請選擇地區",
            "search_multi_loc5": "請選擇地區",
            "_rdo_2": "1",
            "search_work6": "",
            "search_work7": "請選擇職務",
            "search_multi_loc6": "請選擇地區",
            "search_work8": "請選擇職務",
            "search_multi_loc7": "請選擇地區",
            "find_sf_subj_mode1": "",
            "s_find_sf_subj_mode1": "",
            "find_se_work_mode1": "",
            "s_find_se_work_mode1": "",
            "order_by": "neworder",
            "order_ascend": "desc",
            "strrec": "0",#PAGE!HERE!!!
            "search_key_word": "Android",
            "search_type": "job",
            "us_menu": "",
            "search_item": "1",
            "search_from": "joblist",
            "job_show_type": "L"
            }
    payload["strrec"]=index*20
    res=r.post(url,data=payload)
    res.encoding="UTF-8"
    html=res.text
    from bs4 import BeautifulSoup
    import re
    soup=BeautifulSoup(html,"lxml")
    for s in soup.select(".jobname"):
        if len(s.text.split("LINE"))==1:
            joblist.append(s.text.replace(".",""))

for j in joblist:
    print(j)
# Out:
# 【2018研發替代役】Linux/Android工
# Android軟體工程師(台中市)
# (中和)Android軟韌體資深/高/工程師
# (中和) IOT  Embedded Linux/Androi
# (中和) Android智慧型手機 Framework/
# R-Android 開發工程師
# Android App 軟體開發工程師(台北/
# Android軟體工程師I
# D4000 APP程式開發工程師(Android)
# (資深)App軟體工程師 - Android/iOS
# 前端工程師(Windows/Android)
# Sr Linux/Android Software Engineer
# (新竹) Android工程師/高級工程師
# Android Developer
# 研發部／Android工程師
# Android 高級工程師
# Android 工程師
# Android應用工程師(內湖)－71101
# android/ios APP工程師 (E0802)
# Android工程師(支付服務) (E0804)
# 軟體專案獨立工程師
# APP軟體開發工程師
# 《AI-04》FW/Software Engineer(高
# 資訊工程師 (MES)
# 工程類(台北)-Java IOT工程師
# YouBike-台中-資訊創新研發工程師
# 資深系統設計師
# L-APP行銷文案管理師(日文)
# 行動裝置APP開發工程師
# 資訊工程師 (電子商務)
# 資訊部儲備主管
# 資訊部儲備幹部
# 新專案-APP開發工程師
# 程式設計師
# 行動裝置APP程式設計師
# ASPNET程式設計師
# 資深後端軟體工程師
# 資深資料庫系統工程師／DevOps
# 資深前端軟體工程師 - Frontend Deve
# Senior Embedded System Engineer (I
# 雲端多媒體/影音串流軟體研發工程
# 雲端多媒體 Mobile App Developer -
# 軟體 - Embedded Driver /OS /Midwar
# APP軟體研發工程師 - J1413
# (新竹)Linux Driver軟體設計工程師/
# (台北) 應用程式開發工程師/高級工
# 【資訊工程類】資訊工程師 (山鶯廠
# ✅✅✅APP軟體工程師✅✅✅
# AKA資訊處_系統開發工程師
# APP開發工程師
# (資深)UI/UX設計師
# 資深軟體測試工程師/Lead
# 系統整合工程師
# 週休二日~軟體測試工程師
# (正職非派遣)軟體研發經理
# JAVA工程師(專員級)
# JAVA工程師(專員級)
# 系統分析師
# 智慧手機程式開發工程師
# APP開發工程師
# 後端軟體工程師(福利佳)
# 軟體工程師/技術支援工程師
# 手機維修師
# APP開發人員
# 電子部經理
# 資訊總監
# 門市人員、門市業務
# 軟體工程師
# 軟體工程師
# 軟體測試工程師(E0802)

# %%
len(joblist)
# Out:
# 70

# %%
import requests as r
joblist=[]
for index in range(0,5):
    url="https://www.yes123.com.tw/admin/job_refer_list.asp"
    head={}
    payload={
            "find_key1": "Android",
            "search_feature": "",
            "search_work": "請選擇職務",
            "search_multi_loc": "請選擇地區 ",
            "_rdo_1": "1",
            "search_subj": "",
            "search_work4": "請選擇職務",
            "search_multi_loc4": "請選擇地區",
            "search_multi_loc5": "請選擇地區",
            "_rdo_2": "1",
            "search_work6": "",
            "search_work7": "請選擇職務",
            "search_multi_loc6": "請選擇地區",
            "search_work8": "請選擇職務",
            "search_multi_loc7": "請選擇地區",
            "find_sf_subj_mode1": "",
            "s_find_sf_subj_mode1": "",
            "find_se_work_mode1": "",
            "s_find_se_work_mode1": "",
            "order_by": "neworder",
            "order_ascend": "desc",
            "strrec": "0",#PAGE!HERE!!!
            "search_key_word": "Android",
            "search_type": "job",
            "us_menu": "",
            "search_item": "1",
            "search_from": "joblist",
            "job_show_type": "L"
            }
    payload["strrec"]=index*20
    res=r.post(url,data=payload)
    res.encoding="UTF-8"
    html=res.text
    from bs4 import BeautifulSoup
    import re
    soup=BeautifulSoup(html,"lxml")
    for s in soup.select(".jobname"):
        if len(s.text.split("LINE"))==1:
            joblist.append(s.text.replace(".",""))

for j in joblist:
    print(j)
